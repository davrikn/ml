# %%
import pandas as pd
from autogluon.timeseries import TimeSeriesDataFrame, TimeSeriesPredictor
import utils

# %%
location = 'A'
x_train, x_train_estimated, x_test = utils.preprocess_category(location)
x_train.drop(["time"], axis=1, inplace=True)
x_train_estimated.drop(["time"], axis=1, inplace=True)

x_train['date_forecast'] = pd.to_datetime(x_train['date_forecast'])
x_train_estimated['date_forecast'] = pd.to_datetime(x_train_estimated['date_forecast'])

x_test.fillna(0, inplace=True)

x_train['ID'] = pd.factorize(x_train['date_forecast'].dt.date)[0]

last_id_x_train = x_train['ID'].max() + 1
x_train_estimated['ID'] = pd.factorize(x_train_estimated['date_forecast'].dt.date)[0] + last_id_x_train

last_id_x_train_estimated = x_train_estimated['ID'].max() + 1
x_test['ID'] = pd.factorize(x_test['date_forecast'].dt.date)[0] + last_id_x_train_estimated

x_train
# Out:
# Total data points: 34085
# Data points to be removed: 0
# /cluster/home/hansal/ml/utils.py:135: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   estimated_df = estimated_df.resample('H').mean()
# /cluster/home/hansal/ml/utils.py:144: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   test_df = test_df.resample('H').mean()
#        absolute_humidity_2m:gm3  air_density_2m:kgm3  ceiling_height_agl:m  \
# 0                         7.700              1.22825           1728.949951
# 1                         7.700              1.22350           1689.824951
# 2                         7.875              1.21975           1563.224976
# 3                         8.425              1.21800           1283.425049
# 4                         8.950              1.21800           1003.500000
# ...                         ...                  ...                   ...
# 29662                     5.800              1.28050           1291.500000
# 29663                     5.575              1.28400              0.000000
# 29664                     5.350              1.28700              0.000000
# 29665                     5.200              1.29050              0.000000
# 29666                     5.000              1.29200              0.000000
#
#        clear_sky_energy_1h:J  clear_sky_rad:W  cloud_base_agl:m  \
# 0                   0.000000             0.00       1728.949951
# 1                   0.000000             0.00       1689.824951
# 2                   0.000000             0.00       1563.224976
# 3                 208.649994             0.75       1283.425049
# 4               32468.150391            23.10       1003.500000
# ...                      ...              ...               ...
# 29662               0.000000             0.00       1192.550049
# 29663               0.000000             0.00        686.900024
# 29664               0.000000             0.00        149.500000
# 29665               0.000000             0.00          0.000000
# 29666               0.000000             0.00          0.000000
#
#             date_forecast  dew_or_rime:idx  dew_point_2m:K  diffuse_rad:W  \
# 0     2019-06-02 22:00:00              0.0      280.299988          0.000
# 1     2019-06-02 23:00:00              0.0      280.299988          0.000
# 2     2019-06-03 00:00:00              0.0      280.649994          0.000
# 3     2019-06-03 01:00:00              0.0      281.674988          0.300
# 4     2019-06-03 02:00:00              0.0      282.500000         11.975
# ...                   ...              ...             ...            ...
# 29662 2022-10-20 20:00:00              0.0      275.799988          0.000
# 29663 2022-10-20 21:00:00              0.0      275.200012          0.000
# 29664 2022-10-20 22:00:00              0.0      274.600006          0.000
# 29665 2022-10-20 23:00:00              0.0      274.174988          0.000
# 29666 2022-10-21 00:00:00              0.0      273.675018          0.000
#
#        ...  sun_elevation:d  super_cooled_liquid_water:kgm2  t_1000hPa:K  \
# 0      ...        -3.774250                             0.0   286.225006
# 1      ...        -4.357250                             0.0   286.899994
# 2      ...        -3.309500                             0.0   286.950012
# 3      ...        -0.822500                             0.0   286.750000
# 4      ...         3.051250                             0.0   286.450012
# ...    ...              ...                             ...          ...
# 29662  ...       -29.704250                             0.0   278.250000
# 29663  ...       -33.860748                             0.0   277.850006
# 29664  ...       -36.270000                             0.0   277.475006
# 29665  ...       -36.614998                             0.0   277.149994
# 29666  ...       -35.368500                             0.0   276.700012
#
#        total_cloud_cover:p  visibility:m  wind_speed_10m:ms  \
# 0               100.000000  40386.476562              3.600
# 1               100.000000  33770.648438              3.350
# 2               100.000000  13595.500000              3.050
# 3               100.000000   2321.850098              2.725
# 4                99.224998  11634.799805              2.550
# ...                    ...           ...                ...
# 29662            47.050003  40105.472656              1.925
# 29663            19.500000  39001.398438              1.675
# 29664             9.700000  35336.726562              1.400
# 29665             4.525000  27164.625000              1.300
# 29666             1.975000  29933.000000              1.400
#
#        wind_speed_u_10m:ms  wind_speed_v_10m:ms  wind_speed_w_1000hPa:ms    ID
# 0                   -3.575               -0.500                      0.0     0
# 1                   -3.350                0.275                      0.0     0
# 2                   -2.950                0.750                      0.0     1
# 3                   -2.600                0.875                      0.0     1
# 4                   -2.350                0.925                      0.0     1
# ...                    ...                  ...                      ...   ...
# 29662                0.475                1.850                      0.0  1236
# 29663                0.250                1.675                      0.0  1236
# 29664                0.050                1.400                      0.0  1236
# 29665               -0.175                1.300                      0.0  1236
# 29666               -0.700                1.175                      0.0  1237
#
# [29667 rows x 84 columns]

# %%
train_data = TimeSeriesDataFrame.from_data_frame(
    x_train,
    id_column="ID",
    timestamp_column="date_forecast"
)

ts_lengths = train_data.num_timesteps_per_item()
items_to_keep = ts_lengths.index[ts_lengths >= 3]
train_data = train_data.query("item_id in @items_to_keep")

train_data = train_data.to_regular_index(freq="H")
print(f"Data has frequency '{train_data.freq}'")
# Out:
# Data has frequency 'H'

# %%
tuning_data = TimeSeriesDataFrame.from_data_frame(
    x_train_estimated,
    id_column="ID",
    timestamp_column="date_forecast"
)

thirty_percent_index = int(len(tuning_data) * 0.3)
tuning_data = tuning_data.iloc[:thirty_percent_index]

ts_lengths = tuning_data.num_timesteps_per_item()
items_to_keep = ts_lengths.index[ts_lengths >= 3]
tuning_data = tuning_data.query("item_id in @items_to_keep")

tuning_data = tuning_data.to_regular_index(freq="H")
print(f"Data has frequency '{tuning_data.freq}'")
tuning_data
# Out:
# Data has frequency 'H'
#                              absolute_humidity_2m:gm3  air_density_2m:kgm3  \
# item_id timestamp
# 1239    2022-10-29 00:00:00                     8.150              1.22975
#         2022-10-29 01:00:00                     8.200              1.22850
#         2022-10-29 02:00:00                     8.375              1.22700
#         2022-10-29 03:00:00                     8.550              1.22325
#         2022-10-29 04:00:00                     8.750              1.22100
# ...                                               ...                  ...
# 1293    2022-12-22 22:00:00                     2.900              1.30200
#         2022-12-22 23:00:00                     2.800              1.30300
# 1294    2022-12-23 00:00:00                     2.700              1.30500
#         2022-12-23 01:00:00                     2.700              1.30500
#         2022-12-23 02:00:00                     2.700              1.30425
#
#                              ceiling_height_agl:m  clear_sky_energy_1h:J  \
# item_id timestamp
# 1239    2022-10-29 00:00:00           1882.000000                    0.0
#         2022-12-22 23:00:00       -49.889500                           0.000
# 1294    2022-12-23 00:00:00       -48.574501                           0.000
#         2022-12-23 01:00:00       -45.054749                           0.000
#         2022-12-23 02:00:00       -39.912498                           0.000
#
#                              t_1000hPa:K  total_cloud_cover:p  visibility:m  \
# item_id timestamp
# 1239    2022-10-29 00:00:00   283.875000           100.000000   3240.425049
#         2022-10-29 01:00:00   284.350006           100.000000   3243.500000
#         2022-10-29 02:00:00   284.524994           100.000000   2528.449951
#         2022-10-29 03:00:00   284.649994           100.000000   2222.024902
#         2022-10-29 04:00:00   284.450012           100.000000   2160.274902
# ...                                  ...                  ...           ...
# 1293    2022-12-22 22:00:00   271.000000            94.375000  10023.674805
#         2022-12-22 23:00:00   270.225006            96.300003   9881.049805
# 1294    2022-12-23 00:00:00   270.399994            98.324997  11071.375000
#         2022-12-23 01:00:00   270.549988            98.275002   8034.725098
#         2022-12-23 02:00:00   270.750000            96.500000  12402.200195
#
#                              wind_speed_10m:ms  wind_speed_u_10m:ms  \
# item_id timestamp
# 1239    2022-10-29 00:00:00              1.500                1.050
#         2022-10-29 01:00:00              1.575                1.000
#         2022-10-29 02:00:00              2.200                1.825
#         2022-10-29 03:00:00              4.550                4.250
#         2022-10-29 04:00:00              6.875                6.725
# ...                                        ...                  ...
# 1293    2022-12-22 22:00:00              2.725                1.425
#         2022-12-22 23:00:00              2.800                1.400
# 1294    2022-12-23 00:00:00              2.400                1.150
#         2022-12-23 01:00:00              2.525                0.950
#         2022-12-23 02:00:00              2.600                0.825
#
#                              wind_speed_v_10m:ms  wind_speed_w_1000hPa:ms
# item_id timestamp
# 1239    2022-10-29 00:00:00                0.975                      0.0
#         2022-10-29 01:00:00                1.200                      0.0
#         2022-10-29 02:00:00                1.175                      0.0
#         2022-10-29 03:00:00                1.625                      0.0
#         2022-10-29 04:00:00                0.925                      0.0
# ...                                          ...                      ...
# 1293    2022-12-22 22:00:00                2.325                      0.0
#         2022-12-22 23:00:00                2.400                      0.0
# 1294    2022-12-23 00:00:00                2.150                      0.0
#         2022-12-23 01:00:00                2.350                      0.0
#         2022-12-23 02:00:00                2.475                      0.0
#
# [1323 rows x 82 columns]

# %%
test_data = TimeSeriesDataFrame.from_data_frame(
    x_test,
    id_column="ID",
    timestamp_column="date_forecast"
)

ts_lengths = test_data.num_timesteps_per_item()
items_to_keep = ts_lengths.index[ts_lengths >= 3]
test_data = test_data.query("item_id in @items_to_keep")

test_data = test_data.to_regular_index(freq="H")
print(f"Data has frequency '{test_data.freq}'")
test_data
# Out:
# Data has frequency 'H'
#                              absolute_humidity_2m:gm3  air_density_2m:kgm3  \
#                              sun_elevation:d  super_cooled_liquid_water:kgm2  \
# item_id timestamp
# 1423    2023-05-01 00:00:00        -10.54100                           0.000
#         2023-05-01 01:00:00         -7.89450                           0.000
#         2023-05-01 02:00:00         -3.81550                           0.000
#         2023-05-01 03:00:00          1.41250                           0.000
#         2023-05-01 04:00:00          7.46850                           0.000
# ...                                      ...                             ...
# 1486    2023-07-03 19:00:00          8.15300                           0.100
#         2023-07-03 20:00:00          3.26800                           0.000
#         2023-07-03 21:00:00         -0.44325                           0.000
#         2023-07-03 22:00:00         -2.75050                           0.075
#         2023-07-03 23:00:00         -3.49750                           0.125
#
#                              t_1000hPa:K  total_cloud_cover:p  visibility:m  \
# item_id timestamp
# 1423    2023-05-01 00:00:00   273.799988            74.949997  29907.500000
#         2023-05-01 01:00:00   273.799988            77.474998  29519.074219
#         2023-05-01 02:00:00   273.849976            88.099998  31009.125000
#         2023-05-01 03:00:00   273.899994            68.599998  34552.500000
#         2023-05-01 04:00:00   273.924988            66.300003  35483.875000
# ...                                  ...                  ...           ...
# 1486    2023-07-03 19:00:00   287.024994            86.150002  44056.375000
#         2023-07-03 20:00:00   286.600006            75.324997  44017.175781
#         2023-07-03 21:00:00   286.100006            76.849998  43302.050781
#         2023-07-03 22:00:00   285.549988            98.324997  40505.851562
#         2023-07-03 23:00:00   285.250000           100.000000  39665.523438
#
#                              wind_speed_10m:ms  wind_speed_u_10m:ms  \
# item_id timestamp
# 1423    2023-05-01 00:00:00              3.950                2.100
#         2023-05-01 01:00:00              3.825                1.925
#         2023-05-01 02:00:00              3.650                1.750
#         2023-05-01 03:00:00              3.500                1.450
#         2023-05-01 04:00:00              3.325                1.300
# ...                                        ...                  ...
# 1486    2023-07-03 19:00:00              2.450                2.075
#         2023-07-03 20:00:00              2.450                2.100
#         2023-07-03 21:00:00              2.575                2.150
#         2023-07-03 22:00:00              2.250                1.800
#         2023-07-03 23:00:00              1.975                1.600
#
#                              wind_speed_v_10m:ms  wind_speed_w_1000hPa:ms
# item_id timestamp
# 1423    2023-05-01 00:00:00                3.350                      0.0
#         2023-05-01 01:00:00                3.300                      0.0
#         2023-05-01 02:00:00                3.200                      0.0
#         2023-05-01 03:00:00                3.150                      0.0
#         2023-05-01 04:00:00                3.050                      0.0
# ...                                          ...                      ...
# 1486    2023-07-03 19:00:00               -1.350                      0.0
#         2023-07-03 20:00:00               -1.250                      0.0
#         2023-07-03 21:00:00               -1.400                      0.0
#         2023-07-03 22:00:00               -1.350                      0.0
#         2023-07-03 23:00:00               -1.175                      0.0
#
# [1536 rows x 81 columns]

# %%
predictor = TimeSeriesPredictor(
    prediction_length=24,
    path="new_testing",
    target="pv_measurement",
    eval_metric="RMSE",
    known_covariates_names=train_data.drop('pv_measurement', axis=1).columns.tolist()
)

# %%
predictor.fit(
    train_data,
    presets="high_quality",
    time_limit=300,
    num_val_windows= 3,
)
# Out:
# ================ TimeSeriesPredictor ================
# TimeSeriesPredictor.fit() called
# Setting presets to: high_quality
# Fitting with arguments:
# {'enable_ensemble': True,
#  'evaluation_metric': 'RMSE',
#  'excluded_model_types': None,
#  'hyperparameter_tune_kwargs': None,
#  'hyperparameters': 'high_quality',
#  'num_val_windows': 3,
#  'prediction_length': 24,
#  'random_seed': None,
#  'target': 'pv_measurement',
#  'time_limit': 300,
#  'verbosity': 2}
# Provided training data set with 29664 rows, 1236 items (item = single time series). Average time series length is 24.0. Data frequency is 'H'.
#
# It is recommended that all time series in train_data have length >= 2 * prediction_length + 1 (at least 49). Otherwise the predictor may not work as expected.
# Please reduce prediction_length or provide longer time series as train_data.
#
# Time series in train_data are too short for the given num_val_windows = 3. Setting num_val_windows = 0
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 predictor.fit(                                                                               │
# │   2 │   train_data,                                                                              │
# │   3 │   presets="high_quality",                                                                  │
# │   4 │   time_limit=300,                                                                          │
# │                                                                                                  │
# │ /cluster/home/hansal/.local/lib/python3.9/site-packages/autogluon/core/utils/decorators.py:31 in │
# │ _call                                                                                            │
# │                                                                                                  │
# │   28 │   │   @functools.wraps(f)                                                                 │
# │   29 │   │   def _call(*args, **kwargs):                                                         │
# │   30 │   │   │   gargs, gkwargs = g(*other_args, *args, **kwargs)                                │
# │ ❱ 31 │   │   │   return f(*gargs, **gkwargs)                                                     │
# │   32 │   │                                                                                       │
# │   33 │   │   return _call                                                                        │
# │   34                                                                                             │
# │                                                                                                  │
# │ /cluster/home/hansal/.local/lib/python3.9/site-packages/autogluon/timeseries/predictor.py:523 in │
# │ fit                                                                                              │
# │                                                                                                  │
# │   520 │   │   │   if num_val_windows > 0:                                                        │
# │   521 │   │   │   │   logger.warning("Multi-window backtesting is disabled (setting num_val_wi   │
# │   522 │   │   │   │   num_val_windows = 0                                                        │
# │ ❱ 523 │   │   num_val_windows = self._validate_num_val_windows(train_data, tuning_data, num_va   │
# │   524 │   │                                                                                      │
# │   525 │   │   logger.info("=====================================================")               │
# │   526                                                                                            │
# │                                                                                                  │
# │ /cluster/home/hansal/.local/lib/python3.9/site-packages/autogluon/timeseries/predictor.py:278 in │
# │ _validate_num_val_windows                                                                        │
# │                                                                                                  │
# │   275 │   │   │   )                                                                              │
# │   276 │   │   │   num_val_windows = max_possible_num_val_windows                                 │
# │   277 │   │   if num_val_windows == 0 and tuning_data is None:                                   │
# │ ❱ 278 │   │   │   raise ValueError("Training is impossible because num_val_windows = 0 and no    │
# │   279 │   │                                                                                      │
# │   280 │   │   return num_val_windows                                                             │
# │   281                                                                                            │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ValueError: Training is impossible because num_val_windows = 0 and no tuning_data is provided

# %%
predictions = predictor.predict(train_data, known_covariates_names=test_data)
predictions
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 predictions = predictor.predict(train_data, known_covariates_names=test_data)                │
# │   2 predictions                                                                                  │
# │   3                                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# TypeError: predict() got an unexpected keyword argument 'known_covariates_names'
